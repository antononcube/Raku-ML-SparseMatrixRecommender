# %% [markdown]
# # Classification workflow
#
# Anton Antonov
# RakuForPrediction at WordPress
# October 2025

# %% [markdown]
# ----
#
# ## Setup

# %%
use Data::Reshapers;
use Data::Importers;
use Data::Summarizers;
use ML::ROCFunctions;

use ML::SparseMatrixRecommender;

# %%
#% js
js-d3-list-line-plot(10.rand xx 40, background => 'none', stroke-width => 2)

# %%
my $title-color = 'Silver';
my $stroke-color = 'SlateGray';
my $tooltip-color = 'LightBlue';
my $tooltip-background-color = 'none';
my $tick-labels-font-size = 10;
my $tick-labels-color = 'Silver';
my $tick-labels-font-family = 'Helvetica';
my $background = '#1F1F1F';
my $color-scheme = 'schemeTableau10';
my $color-palette = 'Inferno';
my $edge-thickness = 3;
my $vertex-size = 6;
my $mmd-theme = q:to/END/;
%%{
  init: {
    'theme': 'forest',
    'themeVariables': {
      'lineColor': 'Ivory'
    }
  }
}%%
END
my %force = collision => {iterations => 0, radius => 10},link => {distance => 180};
my %force2 = charge => {strength => -30, iterations => 4}, collision => {radius => 50, iterations => 4}, link => {distance => 30};

my %opts = :$background, :$title-color, :$edge-thickness, :$vertex-size;
# Out:
# {background => #1F1F1F, edge-thickness => 3, title-color => Silver, vertex-size => 6}

# %% [markdown]
# ----
#
# ## Ingestion

# %%
my $url = 'https://raw.githubusercontent.com/antononcube/MathematicaVsR/refs/heads/master/Data/MathematicaVsR-Data-Mushroom.csv';
my @dsData = data-import($url, headers => 'auto');

@dsData.&dimensions
# Out:
# (8124 24)

# %%
deduce-type(@dsData);
# Out:
# Vector(Assoc(Atom((Str)), Atom((Str)), 24), 8124)

# %% [markdown]
# ---
#
# ## Preliminary data analysis tabulation

# %% [markdown]
# Here is a summary of the mushroom data:

# %%
my @field-names = <cap-Shape cap-Surface cap-Color bruises? odor gill-Attachment gill-Spacing gill-Size gill-Color edibility>;
sink records-summary(@dsData, :@field-names)
# Out:
# +-----------------+-----------------+-----------------+---------------+-----------------+------------------+-----------------+----------------+-------------------+-------------------+
# | cap-Shape       | cap-Surface     | cap-Color       | bruises?      | odor            | gill-Attachment  | gill-Spacing    | gill-Size      | gill-Color        | edibility         |
# +-----------------+-----------------+-----------------+---------------+-----------------+------------------+-----------------+----------------+-------------------+-------------------+
# | convex  => 3656 | scaly   => 3244 | brown   => 2284 | False => 4748 | none    => 3528 | free     => 7914 | close   => 6812 | broad  => 5612 | buff      => 1728 | edible    => 4208 |
# | flat    => 3152 | smooth  => 2556 | gray    => 1840 | True  => 3376 | foul    => 2160 | attached => 210  | crowded => 1312 | narrow => 2512 | pink      => 1492 | poisonous => 3916 |
# | knobbed => 828  | fibrous => 2320 | red     => 1500 |               | spicy   => 576  |                  |                 |                | white     => 1202 |                   |
# | bell    => 452  | grooves => 4    | yellow  => 1072 |               | fishy   => 576  |                  |                 |                | brown     => 1048 |                   |
# | sunken  => 32   |                 | white   => 1040 |               | almond  => 400  |                  |                 |                | gray      => 752  |                   |
# | conical => 4    |                 | buff    => 168  |               | anise   => 400  |                  |                 |                | chocolate => 732  |                   |
# |                 |                 | pink    => 144  |               | pungent => 256  |                  |                 |                | purple    => 492  |                   |
# |                 |                 | (Other) => 76   |               | (Other) => 228  |                  |                 |                | (Other)   => 678  |                   |
# +-----------------+-----------------+-----------------+---------------+-----------------+------------------+-----------------+----------------+-------------------+-------------------+

# %% [markdown]
# Before classifying for edibility consider this relationship between edibility and odor:

# %%
cross-tabulate(@dsData, 'odor', 'edibility')
==> to-pretty-table()
# Out:
# +----------+-----------+--------+
# |          | poisonous | edible |
# +----------+-----------+--------+
# | almond   |           |  400   |
# | anise    |           |  400   |
# | creosote |    192    |        |
# | fishy    |    576    |        |
# | foul     |    2160   |        |
# | musty    |     36    |        |
# | none     |    120    |  3408  |
# | pungent  |    256    |        |
# | spicy    |    576    |        |
# +----------+-----------+--------+

# %% [markdown]
# We can see that mushrooms with any odor are much more likely to be poisonous. Alternatively, mushrooms without bruise are much more likely to be poisonous:

# %%
cross-tabulate(@dsData, 'bruises?', 'edibility')
==> to-pretty-table()
# Out:
# +-------+--------+-----------+
# |       | edible | poisonous |
# +-------+--------+-----------+
# | False |  1456  |    3292   |
# | True  |  2752  |    624    |
# +-------+--------+-----------+

# %% [markdown]
# ---
#
# ## Procedure outline

# %% [markdown]
# Let us make a full blown classification workflow with the following steps:
#
# - Split the data into training and testing sets
# - Make an SMR object over the training set
# - Classify with the SMR object all records of the testing set
# - Derive (and display) classifier metrics:
#     - Confusion matrix
#     - ROC plots

# %% [markdown]
# ---
#
# ## SMR object creation

# %% [markdown]
# Split the data:

# %%
my (@dsTraining, @dsTesting);
with take-drop(@dsData, floor(0.75 * @dsData.elems)) {
    @dsTraining = select-columns($_.head, ['id', |@field-names]); 
    @dsTesting =  select-columns($_.tail, ['id', |@field-names]); 
}

say deduce-type(@dsTraining);
say deduce-type(@dsTesting);
# Out:
# Vector(Assoc(Atom((Str)), Atom((Str)), 11), 6093)
# Vector(Assoc(Atom((Str)), Atom((Str)), 11), 2031)

# %%
@dsTraining.&dimensions
# Out:
# (6093 11)

# %% [markdown]
# Create a Sparse Matrix Recommender (SMR) object with the training data:

# %%
my $smrObj = 
    ML::SparseMatrixRecommender.new(:native)
    .create-from-wide-form(
        @dsTraining,
        item-column-name => "id",
        tag-types => Whatever,
        :add-tag-types-to-column-names,
        tag-value-separator => ":")
    .apply-term-weight-functions("IDF", "None", "Cosine")
# Out:
# ML::SparseMatrixRecommender(:matrix-dimensions((6093, 50)), :density(0.2), :tag-types(("gill-Spacing", "gill-Attachment", "gill-Color", "cap-Color", "bruises?", "edibility", "cap-Shape", "gill-Size", "odor", "cap-Surface")))

# %% [markdown]
# Here is an example classification:

# %%
my $prof = @dsTesting.pick.grep(*.key ∉ <id edibility>).List;
my @prof = |(($prof».key X~ ':') Z~ $prof».value);
$smrObj.classify-by-profile('edibility', @prof, n-top-nearest-neighbors => 4).take-value
# Out:
# {edibility:poisonous => 1}

# %% [markdown]
# ---
#
# ## Batch classification

# %%
my $n-top-nearest-neighbors = 200;

my @dsResults = @dsTesting.pick(2000).race(:4degree, :500batch).map( -> %record {
    my @prof = %record.grep(*.key ∉ <id edibility>).List;
    @prof = |((@prof».key X~ ':') Z~ @prof».value);
    my %class = $smrObj.classify-by-profile('edibility', @prof, :$n-top-nearest-neighbors).take-value;
    %class .= map({ $_.key.subst('edibility:') => $_.value.Num});

    %( id => %record<id>, actual => %record<edibility>, predicted => %class.sort(-*.value).head.key, |%class)
});

deduce-type(@dsResults)
# Out:
# Vector((Any), 2000)

# %% [markdown]
# Make sure complete set of columns is presented:

# %%
my %empty = :0poisonous, :0edible;
@dsResults = @dsResults.map({ merge-hash(%empty, $_) });
deduce-type(@dsResults)
# Out:
# Vector((Any), 2000)

# %%
sink records-summary(@dsResults)
# Out:
# +-----------------+-------------------------------+-------------------+---------------------------------+-------------------+
# | id              | poisonous                     | predicted         | edible                          | actual            |
# +-----------------+-------------------------------+-------------------+---------------------------------+-------------------+
# | 6920    => 1    | Min    => 0                   | poisonous => 1450 | Min    => 0                     | poisonous => 1483 |
# | 7830    => 1    | 1st-Qu => 0.14604747162022702 | edible    => 550  | 1st-Qu => 0                     | edible    => 517  |
# | 6732    => 1    | Mean   => 0.7385533164894529  |                   | Mean   => 0.2856636064661645    |                   |
# | 7920    => 1    | Median => 1                   |                   | Median => 0.0041753653444676405 |                   |
# | 7975    => 1    | 3rd-Qu => 1                   |                   | 3rd-Qu => 1                     |                   |
# | 7851    => 1    | Max    => 1                   |                   | Max    => 1                     |                   |
# | 7278    => 1    |                               |                   |                                 |                   |
# | (Other) => 1993 |                               |                   |                                 |                   |
# +-----------------+-------------------------------+-------------------+---------------------------------+-------------------+

# %%
#% html
@dsResults.pick(10)
==> to-html(field-names => <id actual predicted edible poisonous>)
# Out:
# <table border="1"><thead><tr><th>id</th><th>actual</th><th>predicted</th><th>edible</th><th>poisonous</th></tr></thead><tbody><tr><td>7213</td><td>poisonous</td><td>poisonous</td><td>0</td><td>1</td></tr><tr><td>6140</td><td>poisonous</td><td>poisonous</td><td>0.03715170278637778</td><td>1</td></tr><tr><td>7990</td><td>poisonous</td><td>poisonous</td><td>0.032208588957055265</td><td>1</td></tr><tr><td>7260</td><td>poisonous</td><td>poisonous</td><td>0.032208588957055265</td><td>1</td></tr><tr><td>6760</td><td>poisonous</td><td>poisonous</td><td>0</td><td>1</td></tr><tr><td>7302</td><td>edible</td><td>edible</td><td>1</td><td>0</td></tr><tr><td>6689</td><td>poisonous</td><td>poisonous</td><td>0</td><td>1</td></tr><tr><td>7076</td><td>poisonous</td><td>poisonous</td><td>0.004149377593360996</td><td>1</td></tr><tr><td>6631</td><td>poisonous</td><td>poisonous</td><td>0</td><td>1</td></tr><tr><td>6384</td><td>poisonous</td><td>poisonous</td><td>0.022744503411675568</td><td>1</td></tr></tbody></table>

# %% [markdown]
# ---
#
# ## Classifier metrics

# %% [markdown]
# Confusion matrix:

# %%
my $ct = cross-tabulate(@dsResults, "actual", "predicted");
to-pretty-table($ct)
# Out:
# +-----------+-----------+--------+
# |           | poisonous | edible |
# +-----------+-----------+--------+
# | edible    |     52    |  465   |
# | poisonous |    1398   |   85   |
# +-----------+-----------+--------+

# %% [markdown]
# Prettier version using HTML rendering:

# %%
#%html
$ct.map({ (actual => $_.key, |$_.value) })».Hash.sort(*<actual>) 
==> to-html(field-names => <actual edible poisonous>)
# Out:
# <table border="1"><thead><tr><th>actual</th><th>edible</th><th>poisonous</th></tr></thead><tbody><tr><td>edible</td><td>465</td><td>52</td></tr><tr><td>poisonous</td><td>85</td><td>1398</td></tr></tbody></table>

# %% [markdown]
# Receiver Operating Characteristic (ROC) metrics computation:

# %%
my @thRange = [|(0, 0.01 ... 0.4), |(0.4, 0.45 ... 1)].unique.sort;

my @rocs = @thRange.map(-> $th { to-roc-hash('poisonous', 'edible', 
                                                select-columns(@dsResults, 'actual')>>.values.flat, 
                                                select-columns(@dsResults, 'poisonous')>>.values.flat.map({ $_ >= $th ?? 'poisonous' !! 'edible' })) });

deduce-type(@rocs)
# Out:
# Vector(Assoc(Atom((Str)), Atom((Int)), 4), 53)

# %% [markdown]
# Tabulate ROC records:

# %%
#%html
@rocs
==> to-html(field-names => <FalsePositive FalseNegative TrueNegative TruePositive>)
# Out:
# <table border="1"><thead><tr><th>FalsePositive</th><th>FalseNegative</th><th>TrueNegative</th><th>TruePositive</th></tr></thead><tbody><tr><td>517</td><td>0</td><td>0</td><td>1483</td></tr><tr><td>294</td><td>29</td><td>223</td><td>1454</td></tr><tr><td>197</td><td>43</td><td>320</td><td>1440</td></tr><tr><td>185</td><td>44</td><td>332</td><td>1439</td></tr><tr><td>154</td><td>50</td><td>363</td><td>1433</td></tr><tr><td>154</td><td>50</td><td>363</td><td>1433</td></tr><tr><td>136</td><td>51</td><td>381</td><td>1432</td></tr><tr><td>113</td><td>56</td><td>404</td><td>1427</td></tr><tr><td>111</td><td>56</td><td>406</td><td>1427</td></tr><tr><td>110</td><td>56</td><td>407</td><td>1427</td></tr><tr><td>106</td><td>56</td><td>411</td><td>1427</td></tr><tr><td>106</td><td>56</td><td>411</td><td>1427</td></tr><tr><td>106</td><td>56</td><td>411</td><td>1427</td></tr><tr><td>78</td><td>60</td><td>439</td><td>1423</td></tr><tr><td>78</td><td>60</td><td>439</td><td>1423</td></tr><tr><td>68</td><td>63</td><td>449</td><td>1420</td></tr><tr><td>66</td><td>64</td><td>451</td><td>1419</td></tr><tr><td>66</td><td>65</td><td>451</td><td>1418</td></tr><tr><td>66</td><td>65</td><td>451</td><td>1418</td></tr><tr><td>65</td><td>65</td><td>452</td><td>1418</td></tr><tr><td>62</td><td>65</td><td>455</td><td>1418</td></tr><tr><td>62</td><td>66</td><td>455</td><td>1417</td></tr><tr><td>60</td><td>66</td><td>457</td><td>1417</td></tr><tr><td>60</td><td>67</td><td>457</td><td>1416</td></tr><tr><td>60</td><td>67</td><td>457</td><td>1416</td></tr><tr><td>60</td><td>68</td><td>457</td><td>1415</td></tr><tr><td>58</td><td>68</td><td>459</td><td>1415</td></tr><tr><td>56</td><td>69</td><td>461</td><td>1414</td></tr><tr><td>56</td><td>69</td><td>461</td><td>1414</td></tr><tr><td>56</td><td>69</td><td>461</td><td>1414</td></tr><tr><td>56</td><td>70</td><td>461</td><td>1413</td></tr><tr><td>56</td><td>70</td><td>461</td><td>1413</td></tr><tr><td>56</td><td>70</td><td>461</td><td>1413</td></tr><tr><td>54</td><td>70</td><td>463</td><td>1413</td></tr><tr><td>54</td><td>70</td><td>463</td><td>1413</td></tr><tr><td>54</td><td>71</td><td>463</td><td>1412</td></tr><tr><td>54</td><td>73</td><td>463</td><td>1410</td></tr><tr><td>54</td><td>73</td><td>463</td><td>1410</td></tr><tr><td>54</td><td>73</td><td>463</td><td>1410</td></tr><tr><td>54</td><td>74</td><td>463</td><td>1409</td></tr><tr><td>54</td><td>74</td><td>463</td><td>1409</td></tr><tr><td>53</td><td>75</td><td>464</td><td>1408</td></tr><tr><td>53</td><td>77</td><td>464</td><td>1406</td></tr><tr><td>53</td><td>79</td><td>464</td><td>1404</td></tr><tr><td>53</td><td>79</td><td>464</td><td>1404</td></tr><tr><td>52</td><td>82</td><td>465</td><td>1401</td></tr><tr><td>52</td><td>84</td><td>465</td><td>1399</td></tr><tr><td>52</td><td>84</td><td>465</td><td>1399</td></tr><tr><td>52</td><td>84</td><td>465</td><td>1399</td></tr><tr><td>52</td><td>85</td><td>465</td><td>1398</td></tr><tr><td>52</td><td>85</td><td>465</td><td>1398</td></tr><tr><td>52</td><td>85</td><td>465</td><td>1398</td></tr><tr><td>52</td><td>85</td><td>465</td><td>1398</td></tr></tbody></table>

# %% [markdown]
# Plot ROC functions (False Positive Rate vs True Positive Rate):

# %%
text-list-plot(roc-functions('FPR')(@rocs), roc-functions('TPR')(@rocs),
                width => 70, height => 25, 
                x-label => 'FPR', y-label => 'TPR', 
                x-limit => (0, 1))
# Out:
# ++------------+-------------+------------+-------------+------------++
# |                                                                    |
# +                                                                   *+  1.00
# |                                                                    |
# |                                                                    |
# |                                                                    |
# +                                                                    +  0.99
# |                                                                    |
# |                                                                    |
# +                                      *                             +  0.98
# |                                                                    |
# |                                                                    |       T
# +                        * *                                         +  0.97 P
# |                                                                    |       R
# |                  * *                                               |
# |              **                                                    |
# +          *                                                         +  0.96
# |        **                                                          |
# |       **                                                           |
# +       *                                                            +  0.95
# |       *                                                            |
# |       *                                                            |
# |       *                                                            |
# +                                                                    +  0.94
# ++------------+-------------+------------+-------------+------------++
#  0.00         0.20          0.40         0.60          0.80         1.00
#                                  FPR
